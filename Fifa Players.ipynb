# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fifa_players.csv')

# %%
df
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
df.describe()
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17708.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.687014e+06   21995.593750                       0.392168
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# national_team             17097
# national_team_position    17097
# national_rating           17097
# national_jersey_number    17097
# release_clause_euro        1837
# value_euro                  255
# wage_euro                   246
# positions                     0
# birth_date                    0
# name                          0
# dtype: int64

# %%
print("Средний возраст:", df['age'].mean())
print("Минимальный возраст:", df['age'].min())
print("Максимальный возраст:", df['age'].max())
# Out:
# Средний возраст: 25.56544502617801
# Минимальный возраст: 17
# Максимальный возраст: 46

# %%
sns.histplot(df['overall_rating'], bins=20, kde=True)
plt.title('Распределение рейтинга игроков')
plt.xlabel('Overall')
plt.ylabel('Количество игроков')
plt.show()

# %%
df[df['age'] <= 23][['name', 'age', 'value_euro', 'overall_rating']].sort_values(by='value_euro', ascending=False).head(10)
# Out:
#                 name  age  value_euro  overall_rating
# 6          K. Mbappé   20  81000000.0              88
# 17915        L. Sané   23  61000000.0              86
# 17897        D. Alli   22  51500000.0              85
# 44        O. Dembélé   21  46000000.0              84
# 35        A. Martial   23  42500000.0              84
# 43     Marco Asensio   23  41500000.0              84
# 17836  Gabriel Jesus   21  41000000.0              83
# 36         T. Werner   23  40000000.0              84
# 17838    M. Rashford   21  37500000.0              83
# 37           N. Süle   23  36500000.0              84

# %%
df['nationality'].value_counts().head(10)
# 10 самых популярных национальностей
# Out:
# nationality
# England        1658
# Germany        1199
# Spain          1070
# France          925
# Argentina       904
# Brazil          832
# Italy           655
# Colombia        624
# Japan           466
# Netherlands     441
# Name: count, dtype: int64

# %%
# График: зависимость между возрастом и потенциалом
sns.scatterplot(data=df, x='age', y='potential', alpha=0.5)
plt.title('Потенциал в зависимости от возраста')
plt.show()

# %%
# Boxplot: Рейтинг игроков по позициям
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='positions', y='overall_rating')
plt.title('Рейтинг по позициям')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['value_euro']/1e6, bins=30, kde=True)
plt.xlabel('Стоимость (в миллионах евро)')
plt.ylabel('Количество игроков')
plt.title('Распределение стоимости игроков')
plt.show()

# %%
#Связь между рейтингом и стоимостью
plt.figure(figsize=(10, 6))
sns.scatterplot(x='overall_rating', y='value_euro', data=df, alpha=0.5)
plt.title('Зависимость стоимости от общего рейтинга')
plt.xlabel('Рейтинг')
plt.ylabel('Стоимость (EUR)')
plt.show()

# %%
#Самые универсальные игроки — с несколькими позициями
df['num_positions'] = df['positions'].apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
df[['name', 'positions', 'num_positions']].sort_values(by='num_positions', ascending=False).head(10)
# Out:
#                  name      positions  num_positions
# 222        M. Philipp   ST,CF,LM,CAM              4
# 2506        P. Becker   RM,CAM,CM,LM              4
# 15715       M. Frantz   CM,RM,CDM,LM              4
# 15152    J. Gutiérrez    CM,LM,RB,RM              4
# 16340      E. Cardona   LW,CAM,LM,CM              4
# 404        J. Willems  LWB,LB,LM,CDM              4
# 17914  Bernardo Silva   CAM,CM,RW,RM              4
# 16095     Óscar Plano   LM,RM,CAM,ST              4
# 17311   Sergio García    ST,LM,LW,RW              4
# 673      L. Melgarejo    LM,RM,ST,LB              4

# %%
top_countries = df['nationality'].value_counts().head(15)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title('Топ 15 стран по числу игроков')
plt.xlabel('Количество игроков')
plt.ylabel('Страна')
plt.show()

# %%
positions_var = df.groupby('positions')['overall_rating'].var().sort_values(ascending=False).head(10)
positions_var.plot(kind='barh', figsize=(10,5), color='tomato')
plt.title('Дисперсия рейтинга по позициям')
plt.xlabel('Дисперсия')
plt.ylabel('Позиция')
plt.show()
